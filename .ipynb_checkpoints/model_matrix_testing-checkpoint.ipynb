# %%
pip install import-ipynb -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import import_ipynb
from turkish_toxicity_classification import classify, load_dataset, create_matrix

# %%
X, y, df = load_dataset(path  = 'datasets/turkish_dataset//turkce_cumleler_kokler_corrected_50k.csv', rows = 2000)
print("\nVeri yuklendi!")
# Out:
# Veri yuklendi!

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="LOG", vectorizerType="BOW")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz
# Out:
# Model Performansı:
# Accuracy: 0.8943396226415095
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.91      6756
#            1       0.94      0.83      0.88      5964
#
#     accuracy                           0.89     12720
#    macro avg       0.90      0.89      0.89     12720
# weighted avg       0.90      0.89      0.89     12720

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="LOG", vectorizerType="TF")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz
# Out:
# Model Performansı:
# Accuracy: 0.8892295597484277
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      6756
#            1       0.93      0.83      0.88      5964
#
#     accuracy                           0.89     12720
#    macro avg       0.89      0.89      0.89     12720
# weighted avg       0.89      0.89      0.89     12720

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="SVM", vectorizerType="BOW")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz
# Out:
# Model Performansı:
# Accuracy: 0.8955974842767296
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91      6756
#            1       0.95      0.82      0.88      5964
#
#     accuracy                           0.90     12720
#    macro avg       0.91      0.89      0.89     12720
# weighted avg       0.90      0.90      0.89     12720

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="SVM", vectorizerType="TF")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="MNB", vectorizerType="BOW")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="MNB", vectorizerType="TF")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="DT", vectorizerType="BOW")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="DT", vectorizerType="TF")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="KNN", vectorizerType="BOW")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="KNN", vectorizerType="TF")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="RF", vectorizerType="BOW")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz

# %%
# Modeli eğit ve sınıflandır
y_test, y_pred, classifier = classify(X, y, modelType="RF", vectorizerType="TF")
#Modeller: SVM, LOG, MNB, DT, KNN, RF
#Vektörleştirmeler: BOW, TF

if y_test is not None and y_pred is not None:
    create_matrix(y_test, y_pred, classifier)   # Confusion Matrix'i çiz
